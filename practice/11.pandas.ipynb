# %%
import pandas as pd 
df = pd.read_csv("bill.csv")
df
# Out:
#      student name  rollno  marks percentage
# 0  Ritik Humagain      22   3000        88%
# 1  Rajat Adhikari      44   5500        50%

# %%
df = pd.read_csv("Salary Data.csv")
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df.shape # To find the shape of the csv file
# Out:
# (375, 6)

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.head(10)
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 1  28.0  Female        Master's           Data Analyst                  3.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 3  36.0  Female      Bachelor's        Sales Associate                  7.0
# 4  52.0    Male        Master's               Director                 20.0
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# 6  120000.0
# 7   80000.0
# ...

# %%
df.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df.tail(10)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 365  43.0    Male        Master's          Director of Marketing
# 366  31.0  Female      Bachelor's       Junior Financial Analyst
# 367  41.0    Male      Bachelor's         Senior Product Manager
# 368  44.0  Female             PhD           Senior Data Engineer
# 369  33.0    Male      Bachelor's        Junior Business Analyst
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 365                 18.0  170000.0
# 366                  3.0   50000.0
# 367                 14.0  150000.0
# 368                 16.0  160000.0
# 369                  4.0   60000.0
# ...

# %%
df = pd.read_csv("Salary Data.csv",nrows = 6)
df
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                    5   90000
# 1   28  Female        Master's       Data Analyst                    3   65000
# 2   45    Male             PhD     Senior Manager                   15  150000
# 3   36  Female      Bachelor's    Sales Associate                    7   60000
# 4   52    Male        Master's           Director                   20  200000
# 5   29    Male      Bachelor's  Marketing Analyst                    2   55000

# %%
df[["Age","Gender","Salary"]]

df = pd.read_csv("Salary Data.csv",nrows = 6)
df
# Out:
#    Age  Gender  Salary
# 0   32    Male   90000
# 1   28  Female   65000
# 2   45    Male  150000
# 3   36  Female   60000
# 4   52    Male  200000
# 5   29    Male   55000

# %%
df = pd.read_csv("Salary Data.csv")
df.iloc[0:10:2]
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 4  52.0    Male        Master's               Director                 20.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
#
#      Salary
# 0   90000.0
# 2  150000.0
# 4  200000.0
# 6  120000.0
# 8   45000.0

# %%
df.iloc[0:5,1:4]
# Out:
#    Gender Education Level          Job Title
# 0    Male      Bachelor's  Software Engineer
# 1  Female        Master's       Data Analyst
# 2    Male             PhD     Senior Manager
# 3  Female      Bachelor's    Sales Associate
# 4    Male        Master's           Director

# %%
#filter
df[df["Age"] > 50]
# Out:
#       Age  Gender Education Level                    Job Title  \
# 4    52.0    Male        Master's                     Director
# 19   51.0    Male      Bachelor's               Sales Director
# 50   51.0  Female      Bachelor's     Customer Service Manager
# 60   51.0  Female        Master's       Director of Operations
# 83   52.0    Male             PhD     Chief Technology Officer
# 93   52.0  Female        Master's     Senior Marketing Manager
# 121  53.0    Male        Master's        Director of Marketing
# 158  51.0  Female             PhD  Director of Human Resources
# 229  51.0  Female        Master's  Director of Human Resources
#
#      Years of Experience    Salary
# 4                   20.0  200000.0
# 19                  22.0  180000.0
# 50                  22.0  130000.0
# 60                  23.0  170000.0
# 83                  24.0  250000.0
# 93                  25.0  170000.0
# 121                 25.0  180000.0
# 158                 23.0  185000.0
# ...

# %%
filter_data = df[(df["Education Level"] == "PhD")& (df["Age"] > 50)]
filter_data.to_csv("filter_data.csv")

# %%
# Dict to dataframe
data = {
    "name": ["ram","shyam","hari"],
    "age":[34,55,6],
    "add":["kathmandu","bhaktapur","lalitpur"],

}
filter_data = pd.DataFrame(data)
filter_data



# filter_data.to_csv("filter_data.csv")
# Out:
#     name  age        add
# 0    ram   34  kathmandu
# 1  shyam   55  bhaktapur
# 2   hari    6   lalitpur
