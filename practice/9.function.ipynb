# %%
# to calculate the area of rectangle
def calculate_sum (l,b,h):  # these are parameter
    area = l * b* h
    return area

result = calculate_sum(3,4,5) #these are argument
print("this is result : ",result)
# Out:
# this is result :  60

# %%
# print hello world 
def helloworld ():
    print("hello world")
    return 
helloworld()
# Out:
# hello world

# %%
#to create a average of 3 number 
def avg (a,b,c):
    average = (a + b + c) / 3
    return average
avg(2,5,6)
# Out:
# 4.333333333333333

# %%
#Built in function 
#print()
#len()
#type()
#range()

# %%
#recursive function
def hello():
    print("helloworld")
    x = input("enter y for more print ")
    if x == "y":
        hello()
    return 0
hello()
# Out:
# helloworld
# helloworld
# helloworld
# helloworld
# helloworld
