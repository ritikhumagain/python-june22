# %%
t = (2,3,4,5,)
print(t[0])
# Out:
# 2

# %%
#in tuple we can do max min sum 
# no append insert extend no del , pop , remove 

# when tuple is used 
gender = ("male","female")
attend = ("yes","no")
print(type(gender))
# Out:
# <class 'tuple'>

# %%
a = 10,33,33,45,66
print(type(a))
# Out:
# <class 'tuple'>

# %%
a = (1,2,3,4)
b = list(a)
print(b)
c = tuple(b)
print(c)
# Out:
# [1, 2, 3, 4]
# (1, 2, 3, 4)

# %%
a = ("apple", 'ball','cat','dog')
list(a)
del b [0]
a = tuple(b)
