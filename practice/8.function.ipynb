# %%
# predefined 
# print() int() float() str() list() tuple()


# userdefined function
def hello():
    print("hello world")

hello()
# Out:
# hello world

# %%
def cal ():
    l = 25 
    b = 10 
    h = 5 
    a = l*b 
    v = a *h
    print("The area = ", a )
