# %%
# Out:
# bhaktapur
# {'name': 'Ritik', 'Age': 25, 'city': 'bhaktapur', 'study': 'bece'}
# {'name': 'Ritik', 'Age': 25, 'city': 'bhaktapur', 'study': 'bece'}

# %%
# dict 
# indexing 
# multiple data and duplicate data 
# ordered
# mutable 

student_details = { 
    "name":"ritik",
    "roll":20,
    "height":10.2,
    "address":"kathmandu",
    "religion":"hindu"

}
print(student_details)
print(type(student_details))
print(len(student_details))
# Out:
# {'name': 'ritik', 'roll': 20, 'height': 10.2, 'address': 'kathmandu', 'religion': 'hindu'}
# <class 'dict'>
# 5

# %%
d = dict()
d.update({"name":"ritik","age":20,"name":"rajat"})
print(d)
# Out:
# {'name': 'rajat', 'age': 20}

# %%
d = dict()
c = 0 
for i in range(int(input("enter no of student:"))):
    name = input("enter your name")
    phone_number = int(input("enter your name "))
    # c += 0
    d.update({"s.no":i,"student_name:":name,"Contact_no:":phone_number})

print(d)
# Out:
# {'s.no': 3, 'student_name:': 'samikshy', 'Contact_no:': 3333}

# %%
student_details = { 
    "name": "ritik",
    "roll": 20,
    "height": 10.2,
    "address": "kathmandu",
    "religion": "hindu"
}

for key in student_details:
    print(key)
# Out:
# name
# roll
# height
# address
# religion

# %%
student_details = { 
    "name": "ritik",
    "roll": 20,
    "height": 10.2,
    "address": "kathmandu",
    "religion": "hindu"
}

for key,value in student_details.items():
    print(key,value)
# Out:
# name ritik
# roll 20
# height 10.2
# address kathmandu
# religion hindu

# %%
d = { "ram ":9841990}
print(d.get("ram"))
print(d)
# Out:
# None
# {'ram ': 9841990}

# %%
d = {"ram":[9841,9849]}
print(d.get("ram").get)
# Out:
# 9841990

# %%
d = [{'name':"ritik",'age':20},{'name':"rajat","age":30}]
d[1].get('name')
# Out:
# 'ritik'

# %%
list 
list are the main part and there is the only the main ther
