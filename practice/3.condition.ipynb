# %%
num = int(input("Enter a number: "))
# Expected:
# 10  → Positive
# -5  → Negative
# 0   → Zero
if (num>0):
    print("positive number")
elif(num<0):
    print("number is negative")
else:
    print("number is 0")
# Out:
# number is 0

# %%
#person can voter or not 
age = int(input("Enter your age: "))
# Expected:
# 18 or above → You can vote
# below 18    → You cannot vote yet
if (age>19):
    print("You can vote")
else:
    print("You cannot vote yet")
# Out:
# You cannot vote yet

# %%
# Q3. Check if a number is even or odd:
number=int(input("enter your number:"))
if (number%2 == 0 ):
    print("number is even")
else:
    print("number is odd")
# Out:
# number is even

# %%
# Q4. Find the largest number among three numbers:
a = int(input("enter the first number"))
b = int(input("enter the second number"))
c = int(input("enter the second number "))
if(a>b and a>c):
    print("a is greater number ")
elif (b>a and b >c ):
    print("b is greater number ")
else:
    print("c is greater number")
# Out:
# a is greater number

# %%
# Q7. Check if a character is vowel or consonant:
letter = input("enter a word:")
if(len(letter)!= 1 or not letter.isalpha()):
    print("enter the single alphabet:")
elif(letter in "aeiou"):
    print("it is vowel:")
else:
    print("not an vowel")
# Out:
# it is vowel:

# %%
what is the
