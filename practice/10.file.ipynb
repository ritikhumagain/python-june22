# %% [markdown]
# <!-- #file in python
# f = open(<filename>,<mode>)
# f.close()
#
# with open (<file_name>,<mode>)as f:
#     <operation> -->

# %%
#create mode x 
f = open("file.txt","x")
f.close()

# %%
#Read mode r
f = open("file.txt","r")
x= f.read()
print(x)
f.close()
# Out:
# 1.hello world
# 2. Hello world
# 3. Hello world
# 4. Hello world
# 5. Hello world
# 6. Hello world
# 7. Hello world

# %%
#mode 
#x = create
#r = read 
#a = append 
#w = write

# %%
#Write mode w
data = "8. Hello World"
f = open("file.txt","w")
f.write(data)
f.close()

# %%
f = open("file.txt","r")
x = f.read()
print(x)
f.close()
# Out:
# 8. Hello World

# %%
data1 = "ritik Humagain"
f = open("file.txt","w")
f.write(data1)
# print(x)
f.close()

# %%
data1 = "\nrajat adhikari "
f = open("file.txt","a")
x = f.write(data1)

print(x)
f.close()
# Out:
# 16

# %%
# data1 = "\nrajat adhikari "
f = open("file.txt","r")
x = f.read()

print(x)
f.close()
# Out:
# ritik Humagain
#  rajat adhikari
# rajat adhikari

# %%
pwd
# Out:
# '/media/ritik-humagain/Programming/python-laptop/python-june22/practice'

# %%
pwd
# Out:
# '/media/ritik-humagain/Programming/python-laptop/python-june22/practice'

# %%
f=open("bill.csv","x")
f.close
# Out:
# <function TextIOWrapper.close()>
